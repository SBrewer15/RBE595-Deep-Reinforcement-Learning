# %%
# Makes the display take up more of the screen
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import gym
import cv2
import os
import time
import json
import random
import collections
import numpy as np

import torch as T
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from collections import deque

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

sns.set_style("white")
# %matplotlib inline

# %%
class DeepQNetwork(nn.Module):
    def __init__(self, lr, n_actions, name, input_dims, chkpt_dir):
        super(DeepQNetwork, self).__init__()
        self.checkpoint_dir = chkpt_dir
        self.checkpoint_file = os.path.join(self.checkpoint_dir, name)

        self.conv1 = nn.Conv2d(input_dims[0], 32, 8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, 4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, 3, stride=1)

        fc_input_dims = self.calculate_conv_output_dims(input_dims)

        self.fc1 = nn.Linear(fc_input_dims, 512)
        self.fc2 = nn.Linear(512, n_actions)

        self.optimizer = optim.RMSprop(self.parameters(), lr=lr)

        self.loss = nn.MSELoss()
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def calculate_conv_output_dims(self, input_dims):
        state = T.zeros(1, *input_dims)
        dims = self.conv1(state)
        dims = self.conv2(dims)
        dims = self.conv3(dims)
        return int(np.prod(dims.size()))

    def forward(self, state):
        conv1 = F.relu(self.conv1(state))
        conv2 = F.relu(self.conv2(conv1))
        conv3 = F.relu(self.conv3(conv2))
        # conv3 shape is BS x n_filters x H x W
        conv_state = conv3.view(conv3.size()[0], -1)
        # conv_state shape is BS x (n_filters * H * W)
        flat1 = F.relu(self.fc1(conv_state))
        actions = self.fc2(flat1)

        return actions

    def save_checkpoint(self):
        print('... saving checkpoint ...')
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        print('... loading checkpoint ...')
        self.load_state_dict(T.load(self.checkpoint_file))

# %%
class ReplayBuffer(object):
    def __init__(self, max_size, input_shape, n_actions):
        self.mem_size = max_size
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size, *input_shape),
                                     dtype=np.float32)
        self.new_state_memory = np.zeros((self.mem_size, *input_shape),
                                         dtype=np.float32)

        self.action_memory = np.zeros(self.mem_size, dtype=np.int64)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)

    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.terminal_memory[index] = done
        self.mem_cntr += 1

    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)
        batch = np.random.choice(max_mem, batch_size, replace=False)

        states = self.state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        states_ = self.new_state_memory[batch]
        terminal = self.terminal_memory[batch]

        return states, actions, rewards, states_, terminal

# %%
class DQNAgent(object):
    def __init__(self, gamma, epsilon, lr, n_actions, input_dims,
                 mem_size, batch_size, eps_min=0.01, eps_dec=5e-7,
                 replace=1000, algo=None, env_name=None, chkpt_dir='tmp/dqn'):
        self.gamma = gamma
        self.epsilon = epsilon
        self.lr = lr
        self.n_actions = n_actions
        self.input_dims = input_dims
        self.batch_size = batch_size
        self.eps_min = eps_min
        self.eps_dec = eps_dec
        self.replace_target_cnt = replace
        self.algo = algo
        self.env_name = env_name
        self.chkpt_dir = chkpt_dir
        self.action_space = [i for i in range(n_actions)]
        self.learn_step_counter = 0

        self.memory = ReplayBuffer(mem_size, input_dims, n_actions)

        self.q_eval = DeepQNetwork(self.lr, self.n_actions,
                                    input_dims=self.input_dims,
                                    name=self.env_name+'_'+self.algo+'_q_eval',
                                    chkpt_dir=self.chkpt_dir)

        self.q_next = DeepQNetwork(self.lr, self.n_actions,
                                    input_dims=self.input_dims,
                                    name=self.env_name+'_'+self.algo+'_q_next',
                                    chkpt_dir=self.chkpt_dir)

    def choose_action(self, observation):
        if np.random.random() > self.epsilon:
            state = T.tensor([observation],dtype=T.float).to(self.q_eval.device)
            actions = self.q_eval.forward(state)
            action = T.argmax(actions).item()
        else:
            action = np.random.choice(self.action_space)

        return action

    def store_transition(self, state, action, reward, state_, done):
        self.memory.store_transition(state, action, reward, state_, done)

    def sample_memory(self):
        state, action, reward, new_state, done = \
                                self.memory.sample_buffer(self.batch_size)

        states = T.tensor(state).to(self.q_eval.device)
        rewards = T.tensor(reward).to(self.q_eval.device)
        dones = T.tensor(done).to(self.q_eval.device)
        actions = T.tensor(action).to(self.q_eval.device)
        states_ = T.tensor(new_state).to(self.q_eval.device)

        return states, actions, rewards, states_, dones

    def replace_target_network(self):
        if self.learn_step_counter % self.replace_target_cnt == 0:
            self.q_next.load_state_dict(self.q_eval.state_dict())

    def decrement_epsilon(self):
        self.epsilon = self.epsilon - self.eps_dec \
                           if self.epsilon > self.eps_min else self.eps_min

    def save_models(self):
        self.q_eval.save_checkpoint()
        self.q_next.save_checkpoint()

    def load_models(self):
        self.q_eval.load_checkpoint()
        self.q_next.load_checkpoint()

    def learn(self):
        if self.memory.mem_cntr < self.batch_size:
            return

        self.q_eval.optimizer.zero_grad()

        self.replace_target_network()

        states, actions, rewards, states_, dones = self.sample_memory()
        indices = np.arange(self.batch_size)

        q_pred = self.q_eval.forward(states)[indices, actions]
        q_next = self.q_next.forward(states_).max(dim=1)[0]

        q_next[dones] = 0.0
        q_target = rewards + self.gamma*q_next

        loss = self.q_eval.loss(q_target, q_pred).to(self.q_eval.device)
        loss.backward()
        self.q_eval.optimizer.step()
        self.learn_step_counter += 1

        self.decrement_epsilon()

# %%
def plot_learning_curve(x, scores, epsilons, filename, lines=None):
    fig=plt.figure()
    ax=fig.add_subplot(111, label="1")
    ax2=fig.add_subplot(111, label="2", frame_on=False)

    ax.plot(x, epsilons, color="C0")
    ax.set_xlabel("Training Steps", color="C0")
    ax.set_ylabel("Epsilon", color="C0")
    ax.tick_params(axis='x', colors="C0")
    ax.tick_params(axis='y', colors="C0")

    N = len(scores)
    running_avg = np.empty(N)
    for t in range(N):
        running_avg[t] = np.mean(scores[max(0, t-20):(t+1)])

    ax2.scatter(x, running_avg, color="C1")
    ax2.axes.get_xaxis().set_visible(False)
    ax2.yaxis.tick_right()
    ax2.set_ylabel('Score', color="C1")
    ax2.yaxis.set_label_position('right')
    ax2.tick_params(axis='y', colors="C1")

    if lines is not None:
        for line in lines:
            plt.axvline(x=line)

    plt.savefig(filename)

class RepeatActionAndMaxFrame(gym.Wrapper):
    def __init__(self, env=None, repeat=4, clip_reward=False, no_ops=0,
                 fire_first=False):
        super(RepeatActionAndMaxFrame, self).__init__(env)
        self.repeat = repeat
        self.shape = env.observation_space.low.shape
        self.frame_buffer = np.zeros_like((2, self.shape))
        self.clip_reward = clip_reward
        self.no_ops = no_ops
        self.fire_first = fire_first

    def step(self, action):
        t_reward = 0.0
        done = False
        for i in range(self.repeat):
            obs, reward, done, info = self.env.step(action)
            if self.clip_reward:
                reward = np.clip(np.array([reward]), -1, 1)[0]
            t_reward += reward
            idx = i % 2
            self.frame_buffer[idx] = obs
            if done:
                break

        max_frame = np.maximum(self.frame_buffer[0], self.frame_buffer[1])
        return max_frame, t_reward, done, info

    def reset(self):
        obs = self.env.reset()
        no_ops = np.random.randint(self.no_ops)+1 if self.no_ops > 0 else 0
        for _ in range(no_ops):
            _, _, done, _ = self.env.step(0)
            if done:
                self.env.reset()
        if self.fire_first:
            assert self.env.unwrapped.get_action_meanings()[1] == 'FIRE'
            obs, _, _, _ = self.env.step(1)

        self.frame_buffer = np.zeros_like((2,self.shape))
        self.frame_buffer[0] = obs

        return obs

class PreprocessFrame(gym.ObservationWrapper):
    def __init__(self, shape, env=None):
        super(PreprocessFrame, self).__init__(env)
        self.shape = (shape[2], shape[0], shape[1])
        self.observation_space = gym.spaces.Box(low=0.0, high=1.0,
                                    shape=self.shape, dtype=np.float32)

    def observation(self, obs):
        new_frame = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)
        resized_screen = cv2.resize(new_frame, self.shape[1:],
                                    interpolation=cv2.INTER_AREA)
        new_obs = np.array(resized_screen, dtype=np.uint8).reshape(self.shape)
        new_obs = new_obs / 255.0

        return new_obs

class StackFrames(gym.ObservationWrapper):
    def __init__(self, env, repeat):
        super(StackFrames, self).__init__(env)
        self.observation_space = gym.spaces.Box(
                            env.observation_space.low.repeat(repeat, axis=0),
                            env.observation_space.high.repeat(repeat, axis=0),
                            dtype=np.float32)
        self.stack = collections.deque(maxlen=repeat)

    def reset(self):
        self.stack.clear()
        observation = self.env.reset()
        for _ in range(self.stack.maxlen):
            self.stack.append(observation)

        return np.array(self.stack).reshape(self.observation_space.low.shape)

    def observation(self, observation):
        self.stack.append(observation)

        return np.array(self.stack).reshape(self.observation_space.low.shape)

def make_env(env_name, shape=(84,84,1), repeat=4, clip_rewards=False,
             no_ops=0, fire_first=False):
    env = gym.make(env_name)
    env = RepeatActionAndMaxFrame(env, repeat, clip_rewards, no_ops, fire_first)
    env = PreprocessFrame(shape, env)
    env = StackFrames(env, repeat)

    return env

# %%
env = make_env('PongNoFrameskip-v4')
#env = gym.make('CartPole-v1')
best_score = -np.inf
load_checkpoint = False
n_games = 250

agent = DQNAgent(gamma=0.99, epsilon=1, lr=0.0001,
                 input_dims=(env.observation_space.shape),
                 n_actions=env.action_space.n, mem_size=50000, eps_min=0.1,
                 batch_size=32, replace=1000, eps_dec=1e-5,
                 chkpt_dir='models/', algo='DQNAgent',
                 env_name='PongNoFrameskip-v4')

if load_checkpoint:
    agent.load_models()

fname = agent.algo + '_' + agent.env_name + '_lr' + str(agent.lr) +'_' \
        + str(n_games) + 'games'
figure_file = 'plots/' + fname + '.png'
# if you want to record video of your agent playing, do a mkdir tmp && mkdir tmp/dqn-video
# and uncomment the following 2 lines.
#env = wrappers.Monitor(env, "tmp/dqn-video",
#                    video_callable=lambda episode_id: True, force=True)
n_steps = 0
scores, eps_history, steps_array = [], [], []

# %%
for i in range(n_games):
    done = False
    observation = env.reset()

    score = 0
    while not done:
        action = agent.choose_action(observation)
        observation_, reward, done, info = env.step(action)
        score += reward

        if not load_checkpoint:
            agent.store_transition(observation, action,
                                 reward, observation_, done)
            agent.learn()
        observation = observation_
        n_steps += 1
    scores.append(score)
    steps_array.append(n_steps)

    avg_score = np.mean(scores[-100:])
    print('episode: ', i,'score: ', score,
         ' average score %.1f' % avg_score, 'best score %.2f' % best_score,
        'epsilon %.2f' % agent.epsilon, 'steps', n_steps)

    if avg_score > best_score:
        if not load_checkpoint:
            agent.save_models()
        best_score = avg_score

    eps_history.append(agent.epsilon)
# Out:
# C:\Users\M323742\Anaconda3\envs\gym\lib\site-packages\ipykernel_launcher.py:34: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ..\torch\csrc\utils\tensor_new.cpp:201.)
# episode:  0 score:  -20.0  average score -20.0 best score -inf epsilon 0.99 steps 1055
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  1 score:  -21.0  average score -20.5 best score -20.00 epsilon 0.98 steps 1907
# episode:  2 score:  -19.0  average score -20.0 best score -20.00 epsilon 0.97 steps 2993
# episode:  3 score:  -21.0  average score -20.2 best score -20.00 epsilon 0.96 steps 3926
# episode:  4 score:  -21.0  average score -20.4 best score -20.00 epsilon 0.95 steps 4810
# episode:  5 score:  -21.0  average score -20.5 best score -20.00 epsilon 0.94 steps 5634
# episode:  6 score:  -20.0  average score -20.4 best score -20.00 epsilon 0.93 steps 6532
# episode:  7 score:  -20.0  average score -20.4 best score -20.00 epsilon 0.92 steps 7594
# episode:  8 score:  -21.0  average score -20.4 best score -20.00 epsilon 0.92 steps 8476
# episode:  9 score:  -21.0  average score -20.5 best score -20.00 epsilon 0.91 steps 9259
# episode:  10 score:  -21.0  average score -20.5 best score -20.00 epsilon 0.90 steps 10164
# episode:  11 score:  -20.0  average score -20.5 best score -20.00 epsilon 0.89 steps 11187
# episode:  12 score:  -21.0  average score -20.5 best score -20.00 epsilon 0.88 steps 11951
# episode:  13 score:  -21.0  average score -20.6 best score -20.00 epsilon 0.87 steps 12857
# episode:  14 score:  -21.0  average score -20.6 best score -20.00 epsilon 0.86 steps 13956
# episode:  15 score:  -21.0  average score -20.6 best score -20.00 epsilon 0.85 steps 14959
# episode:  16 score:  -21.0  average score -20.6 best score -20.00 epsilon 0.84 steps 15843
# episode:  17 score:  -18.0  average score -20.5 best score -20.00 epsilon 0.83 steps 17076
# episode:  18 score:  -21.0  average score -20.5 best score -20.00 epsilon 0.82 steps 17868
# episode:  19 score:  -21.0  average score -20.6 best score -20.00 epsilon 0.81 steps 18801
# episode:  20 score:  -21.0  average score -20.6 best score -20.00 epsilon 0.80 steps 19627
# episode:  21 score:  -21.0  average score -20.6 best score -20.00 epsilon 0.80 steps 20419
# episode:  22 score:  -19.0  average score -20.5 best score -20.00 epsilon 0.79 steps 21492
# episode:  23 score:  -20.0  average score -20.5 best score -20.00 epsilon 0.78 steps 22370
# episode:  24 score:  -21.0  average score -20.5 best score -20.00 epsilon 0.77 steps 23345
# episode:  25 score:  -19.0  average score -20.5 best score -20.00 epsilon 0.76 steps 24470
# episode:  26 score:  -19.0  average score -20.4 best score -20.00 epsilon 0.74 steps 25811
# episode:  27 score:  -21.0  average score -20.4 best score -20.00 epsilon 0.73 steps 27044
# episode:  28 score:  -20.0  average score -20.4 best score -20.00 epsilon 0.72 steps 28028
# episode:  29 score:  -21.0  average score -20.4 best score -20.00 epsilon 0.71 steps 29168
# episode:  30 score:  -20.0  average score -20.4 best score -20.00 epsilon 0.70 steps 30200
# episode:  31 score:  -20.0  average score -20.4 best score -20.00 epsilon 0.69 steps 31420
# episode:  32 score:  -17.0  average score -20.3 best score -20.00 epsilon 0.67 steps 32726
# episode:  33 score:  -19.0  average score -20.3 best score -20.00 epsilon 0.66 steps 33775
# episode:  34 score:  -19.0  average score -20.2 best score -20.00 epsilon 0.65 steps 35091
# episode:  35 score:  -20.0  average score -20.2 best score -20.00 epsilon 0.64 steps 36282
# episode:  36 score:  -18.0  average score -20.2 best score -20.00 epsilon 0.62 steps 37578
# episode:  37 score:  -17.0  average score -20.1 best score -20.00 epsilon 0.61 steps 38994
# episode:  38 score:  -20.0  average score -20.1 best score -20.00 epsilon 0.60 steps 40190
# episode:  39 score:  -18.0  average score -20.0 best score -20.00 epsilon 0.59 steps 41497
# episode:  40 score:  -21.0  average score -20.0 best score -20.00 epsilon 0.57 steps 42633
# episode:  41 score:  -17.0  average score -20.0 best score -20.00 epsilon 0.56 steps 44188
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  42 score:  -16.0  average score -19.9 best score -19.98 epsilon 0.54 steps 45863
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  43 score:  -19.0  average score -19.9 best score -19.88 epsilon 0.53 steps 47142
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  44 score:  -16.0  average score -19.8 best score -19.86 epsilon 0.51 steps 48788
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  45 score:  -19.0  average score -19.8 best score -19.78 epsilon 0.50 steps 50297
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  46 score:  -18.0  average score -19.7 best score -19.76 epsilon 0.48 steps 51853
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  47 score:  -16.0  average score -19.6 best score -19.72 epsilon 0.47 steps 53494
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  48 score:  -18.0  average score -19.6 best score -19.65 epsilon 0.45 steps 55198
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  49 score:  -19.0  average score -19.6 best score -19.61 epsilon 0.43 steps 57048
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  50 score:  -14.0  average score -19.5 best score -19.60 epsilon 0.41 steps 59101
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  51 score:  -20.0  average score -19.5 best score -19.49 epsilon 0.39 steps 60688
# episode:  52 score:  -18.0  average score -19.5 best score -19.49 epsilon 0.38 steps 62265
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  53 score:  -17.0  average score -19.4 best score -19.47 epsilon 0.36 steps 64331
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  54 score:  -11.0  average score -19.3 best score -19.43 epsilon 0.33 steps 66919
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  55 score:  -17.0  average score -19.2 best score -19.27 epsilon 0.31 steps 68598
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  56 score:  -16.0  average score -19.2 best score -19.23 epsilon 0.30 steps 70528
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  57 score:  -18.0  average score -19.2 best score -19.18 epsilon 0.28 steps 72247
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  58 score:  -15.0  average score -19.1 best score -19.16 epsilon 0.25 steps 74843
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  59 score:  -15.0  average score -19.0 best score -19.08 epsilon 0.23 steps 76945
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  60 score:  -18.0  average score -19.0 best score -19.02 epsilon 0.21 steps 78743
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  61 score:  -18.0  average score -19.0 best score -19.00 epsilon 0.20 steps 80518
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  62 score:  -16.0  average score -18.9 best score -18.98 epsilon 0.17 steps 82790
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  63 score:  -14.0  average score -18.9 best score -18.94 epsilon 0.15 steps 85022
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  64 score:  -18.0  average score -18.8 best score -18.86 epsilon 0.13 steps 86873
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  65 score:  -17.0  average score -18.8 best score -18.85 epsilon 0.11 steps 88752
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  66 score:  -17.0  average score -18.8 best score -18.82 epsilon 0.10 steps 90611
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  67 score:  -14.0  average score -18.7 best score -18.79 epsilon 0.10 steps 93089
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  68 score:  -10.0  average score -18.6 best score -18.72 epsilon 0.10 steps 95779
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  69 score:  -9.0  average score -18.5 best score -18.59 epsilon 0.10 steps 98772
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  70 score:  -16.0  average score -18.4 best score -18.46 epsilon 0.10 steps 101731
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  71 score:  -10.0  average score -18.3 best score -18.42 epsilon 0.10 steps 104332
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  72 score:  -16.0  average score -18.3 best score -18.31 epsilon 0.10 steps 107124
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  73 score:  -12.0  average score -18.2 best score -18.27 epsilon 0.10 steps 110320
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  74 score:  -14.0  average score -18.1 best score -18.19 epsilon 0.10 steps 112802
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  75 score:  -14.0  average score -18.1 best score -18.13 epsilon 0.10 steps 115760
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  76 score:  -8.0  average score -17.9 best score -18.08 epsilon 0.10 steps 119042
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  77 score:  -13.0  average score -17.9 best score -17.95 epsilon 0.10 steps 121537
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  78 score:  -7.0  average score -17.7 best score -17.88 epsilon 0.10 steps 124865
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  79 score:  -14.0  average score -17.7 best score -17.75 epsilon 0.10 steps 127501
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  80 score:  -7.0  average score -17.6 best score -17.70 epsilon 0.10 steps 130706
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  81 score:  -11.0  average score -17.5 best score -17.57 epsilon 0.10 steps 133342
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  82 score:  -7.0  average score -17.4 best score -17.49 epsilon 0.10 steps 136670
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  83 score:  -4.0  average score -17.2 best score -17.36 epsilon 0.10 steps 139855
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  84 score:  -13.0  average score -17.2 best score -17.20 epsilon 0.10 steps 142584
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  85 score:  -11.0  average score -17.1 best score -17.15 epsilon 0.10 steps 145615
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  86 score:  -8.0  average score -17.0 best score -17.08 epsilon 0.10 steps 148380
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  87 score:  -4.0  average score -16.8 best score -16.98 epsilon 0.10 steps 151908
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  88 score:  -4.0  average score -16.7 best score -16.83 epsilon 0.10 steps 155184
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  89 score:  -4.0  average score -16.5 best score -16.69 epsilon 0.10 steps 158867
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  90 score:  -5.0  average score -16.4 best score -16.54 epsilon 0.10 steps 162857
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  91 score:  7.0  average score -16.2 best score -16.42 epsilon 0.10 steps 166534
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  92 score:  -12.0  average score -16.1 best score -16.16 epsilon 0.10 steps 169787
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  93 score:  -8.0  average score -16.0 best score -16.12 epsilon 0.10 steps 173605
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  94 score:  -6.0  average score -15.9 best score -16.03 epsilon 0.10 steps 177556
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  95 score:  -10.0  average score -15.9 best score -15.93 epsilon 0.10 steps 180537
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  96 score:  2.0  average score -15.7 best score -15.86 epsilon 0.10 steps 183888
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  97 score:  -5.0  average score -15.6 best score -15.68 epsilon 0.10 steps 187459
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  98 score:  -1.0  average score -15.4 best score -15.57 epsilon 0.10 steps 191108
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  99 score:  -4.0  average score -15.3 best score -15.42 epsilon 0.10 steps 194656
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  100 score:  -1.0  average score -15.1 best score -15.31 epsilon 0.10 steps 198524
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  101 score:  -4.0  average score -14.9 best score -15.12 epsilon 0.10 steps 201769
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  102 score:  5.0  average score -14.7 best score -14.95 epsilon 0.10 steps 205438
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  103 score:  -4.0  average score -14.5 best score -14.71 epsilon 0.10 steps 208654
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  104 score:  2.0  average score -14.3 best score -14.54 epsilon 0.10 steps 211863
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  105 score:  4.0  average score -14.1 best score -14.31 epsilon 0.10 steps 215189
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  106 score:  14.0  average score -13.7 best score -14.06 epsilon 0.10 steps 217967
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  107 score:  4.0  average score -13.5 best score -13.72 epsilon 0.10 steps 221108
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  108 score:  9.0  average score -13.2 best score -13.48 epsilon 0.10 steps 223910
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  109 score:  4.0  average score -12.9 best score -13.18 epsilon 0.10 steps 227403
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  110 score:  7.0  average score -12.7 best score -12.93 epsilon 0.10 steps 230796
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  111 score:  11.0  average score -12.3 best score -12.65 epsilon 0.10 steps 233575
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  112 score:  3.0  average score -12.1 best score -12.34 epsilon 0.10 steps 237029
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  113 score:  19.0  average score -11.7 best score -12.10 epsilon 0.10 steps 239042
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  114 score:  9.0  average score -11.4 best score -11.70 epsilon 0.10 steps 241694
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  115 score:  12.0  average score -11.1 best score -11.40 epsilon 0.10 steps 244217
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  116 score:  13.0  average score -10.7 best score -11.07 epsilon 0.10 steps 247001
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  117 score:  11.0  average score -10.4 best score -10.73 epsilon 0.10 steps 249867
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  118 score:  13.0  average score -10.1 best score -10.44 epsilon 0.10 steps 252567
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  119 score:  18.0  average score -9.7 best score -10.10 epsilon 0.10 steps 254438
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  120 score:  9.0  average score -9.4 best score -9.71 epsilon 0.10 steps 257373
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  121 score:  15.0  average score -9.1 best score -9.41 epsilon 0.10 steps 259898
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  122 score:  10.0  average score -8.8 best score -9.05 epsilon 0.10 steps 262506
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  123 score:  12.0  average score -8.4 best score -8.76 epsilon 0.10 steps 264807
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  124 score:  15.0  average score -8.1 best score -8.44 epsilon 0.10 steps 267062
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  125 score:  13.0  average score -7.8 best score -8.08 epsilon 0.10 steps 269796
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  126 score:  15.0  average score -7.4 best score -7.76 epsilon 0.10 steps 272327
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  127 score:  11.0  average score -7.1 best score -7.42 epsilon 0.10 steps 275041
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  128 score:  14.0  average score -6.8 best score -7.10 epsilon 0.10 steps 277242
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  129 score:  11.0  average score -6.4 best score -6.76 epsilon 0.10 steps 279840
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  130 score:  11.0  average score -6.1 best score -6.44 epsilon 0.10 steps 282212
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  131 score:  9.0  average score -5.8 best score -6.13 epsilon 0.10 steps 284827
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  132 score:  12.0  average score -5.5 best score -5.84 epsilon 0.10 steps 287417
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  133 score:  12.0  average score -5.2 best score -5.55 epsilon 0.10 steps 290237
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  134 score:  15.0  average score -4.9 best score -5.24 epsilon 0.10 steps 292309
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  135 score:  16.0  average score -4.5 best score -4.90 epsilon 0.10 steps 294368
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  136 score:  14.0  average score -4.2 best score -4.54 epsilon 0.10 steps 297074
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  137 score:  3.0  average score -4.0 best score -4.22 epsilon 0.10 steps 300581
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  138 score:  13.0  average score -3.7 best score -4.02 epsilon 0.10 steps 303003
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  139 score:  13.0  average score -3.4 best score -3.69 epsilon 0.10 steps 305694
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  140 score:  13.0  average score -3.0 best score -3.38 epsilon 0.10 steps 308092
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  141 score:  9.0  average score -2.8 best score -3.04 epsilon 0.10 steps 311115
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  142 score:  17.0  average score -2.5 best score -2.78 epsilon 0.10 steps 313395
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  143 score:  12.0  average score -2.1 best score -2.45 epsilon 0.10 steps 315695
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  144 score:  16.0  average score -1.8 best score -2.14 epsilon 0.10 steps 317655
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  145 score:  8.0  average score -1.6 best score -1.82 epsilon 0.10 steps 320342
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  146 score:  15.0  average score -1.2 best score -1.55 epsilon 0.10 steps 322482
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  147 score:  16.0  average score -0.9 best score -1.22 epsilon 0.10 steps 324519
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  148 score:  18.0  average score -0.5 best score -0.90 epsilon 0.10 steps 326715
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  149 score:  9.0  average score -0.3 best score -0.54 epsilon 0.10 steps 329597
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  150 score:  7.0  average score -0.1 best score -0.26 epsilon 0.10 steps 332401
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  151 score:  18.0  average score 0.3 best score -0.05 epsilon 0.10 steps 334323
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  152 score:  15.0  average score 0.7 best score 0.33 epsilon 0.10 steps 336569
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  153 score:  11.0  average score 0.9 best score 0.66 epsilon 0.10 steps 339151
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  154 score:  14.0  average score 1.2 best score 0.94 epsilon 0.10 steps 341452
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  155 score:  14.0  average score 1.5 best score 1.19 epsilon 0.10 steps 343473
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  156 score:  -1.0  average score 1.6 best score 1.50 epsilon 0.10 steps 346441
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  157 score:  6.0  average score 1.9 best score 1.65 epsilon 0.10 steps 349085
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  158 score:  15.0  average score 2.2 best score 1.89 epsilon 0.10 steps 351475
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  159 score:  11.0  average score 2.5 best score 2.19 epsilon 0.10 steps 354322
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  160 score:  13.0  average score 2.8 best score 2.45 epsilon 0.10 steps 356626
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  161 score:  13.0  average score 3.1 best score 2.76 epsilon 0.10 steps 358818
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  162 score:  18.0  average score 3.4 best score 3.07 epsilon 0.10 steps 360794
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  163 score:  15.0  average score 3.7 best score 3.41 epsilon 0.10 steps 363127
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  164 score:  11.0  average score 4.0 best score 3.70 epsilon 0.10 steps 365523
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  165 score:  7.0  average score 4.2 best score 3.99 epsilon 0.10 steps 368320
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  166 score:  14.0  average score 4.5 best score 4.23 epsilon 0.10 steps 370821
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  167 score:  15.0  average score 4.8 best score 4.54 epsilon 0.10 steps 373413
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  168 score:  12.0  average score 5.0 best score 4.83 epsilon 0.10 steps 376001
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  169 score:  9.0  average score 5.2 best score 5.05 epsilon 0.10 steps 378705
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  170 score:  13.0  average score 5.5 best score 5.23 epsilon 0.10 steps 380931
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  171 score:  17.0  average score 5.8 best score 5.52 epsilon 0.10 steps 383101
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  172 score:  11.0  average score 6.1 best score 5.79 epsilon 0.10 steps 385684
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  173 score:  14.0  average score 6.3 best score 6.06 epsilon 0.10 steps 388043
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  174 score:  10.0  average score 6.6 best score 6.32 epsilon 0.10 steps 390637
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  175 score:  13.0  average score 6.8 best score 6.56 epsilon 0.10 steps 393088
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  176 score:  15.0  average score 7.1 best score 6.83 epsilon 0.10 steps 395651
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  177 score:  15.0  average score 7.3 best score 7.06 epsilon 0.10 steps 397937
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  178 score:  16.0  average score 7.6 best score 7.34 epsilon 0.10 steps 400000
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  179 score:  12.0  average score 7.8 best score 7.57 epsilon 0.10 steps 402412
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  180 score:  13.0  average score 8.0 best score 7.83 epsilon 0.10 steps 405033
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  181 score:  16.0  average score 8.3 best score 8.03 epsilon 0.10 steps 407207
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  182 score:  14.0  average score 8.5 best score 8.30 epsilon 0.10 steps 409663
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  183 score:  15.0  average score 8.7 best score 8.51 epsilon 0.10 steps 411955
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  184 score:  14.0  average score 9.0 best score 8.70 epsilon 0.10 steps 414207
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  185 score:  18.0  average score 9.3 best score 8.97 epsilon 0.10 steps 416384
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  186 score:  14.0  average score 9.5 best score 9.26 epsilon 0.10 steps 418869
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  187 score:  17.0  average score 9.7 best score 9.48 epsilon 0.10 steps 421017
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  188 score:  6.0  average score 9.8 best score 9.69 epsilon 0.10 steps 423728
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  189 score:  14.0  average score 10.0 best score 9.79 epsilon 0.10 steps 426263
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  190 score:  20.0  average score 10.2 best score 9.97 epsilon 0.10 steps 428056
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  191 score:  13.0  average score 10.3 best score 10.22 epsilon 0.10 steps 430841
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  192 score:  19.0  average score 10.6 best score 10.28 epsilon 0.10 steps 433005
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  193 score:  15.0  average score 10.8 best score 10.59 epsilon 0.10 steps 435459
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  194 score:  8.0  average score 11.0 best score 10.82 epsilon 0.10 steps 438164
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  195 score:  17.0  average score 11.2 best score 10.96 epsilon 0.10 steps 440499
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  196 score:  17.0  average score 11.4 best score 11.23 epsilon 0.10 steps 442527
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  197 score:  9.0  average score 11.5 best score 11.38 epsilon 0.10 steps 445582
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  198 score:  19.0  average score 11.7 best score 11.52 epsilon 0.10 steps 447449
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  199 score:  15.0  average score 11.9 best score 11.72 epsilon 0.10 steps 449439
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  200 score:  16.0  average score 12.1 best score 11.91 epsilon 0.10 steps 451613
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  201 score:  16.0  average score 12.3 best score 12.08 epsilon 0.10 steps 453744
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  202 score:  17.0  average score 12.4 best score 12.28 epsilon 0.10 steps 455780
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  203 score:  18.0  average score 12.6 best score 12.40 epsilon 0.10 steps 457879
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  204 score:  15.0  average score 12.8 best score 12.62 epsilon 0.10 steps 460099
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  205 score:  17.0  average score 12.9 best score 12.75 epsilon 0.10 steps 461973
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  206 score:  13.0  average score 12.9 best score 12.88 epsilon 0.10 steps 464390
# episode:  207 score:  12.0  average score 12.9 best score 12.88 epsilon 0.10 steps 466902
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  208 score:  17.0  average score 13.0 best score 12.95 epsilon 0.10 steps 468917
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  209 score:  12.0  average score 13.1 best score 13.03 epsilon 0.10 steps 471553
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  210 score:  15.0  average score 13.2 best score 13.11 epsilon 0.10 steps 473793
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  211 score:  12.0  average score 13.2 best score 13.19 epsilon 0.10 steps 476678
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  212 score:  11.0  average score 13.3 best score 13.20 epsilon 0.10 steps 479046
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  213 score:  16.0  average score 13.2 best score 13.28 epsilon 0.10 steps 481241
# episode:  214 score:  14.0  average score 13.3 best score 13.28 epsilon 0.10 steps 483263
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  215 score:  18.0  average score 13.4 best score 13.30 epsilon 0.10 steps 485189
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  216 score:  9.0  average score 13.3 best score 13.36 epsilon 0.10 steps 487809
# episode:  217 score:  17.0  average score 13.4 best score 13.36 epsilon 0.10 steps 489997
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  218 score:  14.0  average score 13.4 best score 13.38 epsilon 0.10 steps 492208
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  219 score:  13.0  average score 13.3 best score 13.39 epsilon 0.10 steps 494846
# episode:  220 score:  15.0  average score 13.4 best score 13.39 epsilon 0.10 steps 497200
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  221 score:  17.0  average score 13.4 best score 13.40 epsilon 0.10 steps 499450
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  222 score:  17.0  average score 13.5 best score 13.42 epsilon 0.10 steps 501480
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  223 score:  17.0  average score 13.5 best score 13.49 epsilon 0.10 steps 503599
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  224 score:  17.0  average score 13.6 best score 13.54 epsilon 0.10 steps 505616
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  225 score:  15.0  average score 13.6 best score 13.56 epsilon 0.10 steps 507728
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  226 score:  15.0  average score 13.6 best score 13.58 epsilon 0.10 steps 510147
# episode:  227 score:  13.0  average score 13.6 best score 13.58 epsilon 0.10 steps 512690
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  228 score:  11.0  average score 13.6 best score 13.60 epsilon 0.10 steps 515032
# episode:  229 score:  4.0  average score 13.5 best score 13.60 epsilon 0.10 steps 517949
# episode:  230 score:  19.0  average score 13.6 best score 13.60 epsilon 0.10 steps 519780
# episode:  231 score:  16.0  average score 13.7 best score 13.60 epsilon 0.10 steps 521895
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  232 score:  15.0  average score 13.7 best score 13.65 epsilon 0.10 steps 524267
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  233 score:  13.0  average score 13.7 best score 13.68 epsilon 0.10 steps 526639
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  234 score:  13.0  average score 13.7 best score 13.69 epsilon 0.10 steps 529052
# episode:  235 score:  17.0  average score 13.7 best score 13.69 epsilon 0.10 steps 531564
# episode:  236 score:  12.0  average score 13.7 best score 13.69 epsilon 0.10 steps 534169
# episode:  237 score:  19.0  average score 13.8 best score 13.69 epsilon 0.10 steps 535996
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  238 score:  17.0  average score 13.9 best score 13.82 epsilon 0.10 steps 538147
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  239 score:  17.0  average score 13.9 best score 13.86 epsilon 0.10 steps 540421
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  240 score:  11.0  average score 13.9 best score 13.90 epsilon 0.10 steps 542707
# episode:  241 score:  14.0  average score 13.9 best score 13.90 epsilon 0.10 steps 545101
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  242 score:  20.0  average score 14.0 best score 13.93 epsilon 0.10 steps 546985
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  243 score:  15.0  average score 14.0 best score 13.96 epsilon 0.10 steps 549071
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  244 score:  18.0  average score 14.0 best score 13.99 epsilon 0.10 steps 550922
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  245 score:  6.0  average score 14.0 best score 14.01 epsilon 0.10 steps 553340
# episode:  246 score:  20.0  average score 14.0 best score 14.01 epsilon 0.10 steps 555091
# ... saving checkpoint ...
# ... saving checkpoint ...
# episode:  247 score:  13.0  average score 14.0 best score 14.04 epsilon 0.10 steps 557543
# episode:  248 score:  18.0  average score 14.0 best score 14.04 epsilon 0.10 steps 559428
# episode:  249 score:  9.0  average score 14.0 best score 14.04 epsilon 0.10 steps 561934

# %%
x = [i+1 for i in range(len(scores))]
plot_learning_curve(steps_array, scores, eps_history, figure_file)

# %%
current_image = env.render(mode = 'rgb_array')

# %%
plt.imshow(current_image)

# %%
 #env.render()
# Out:
# C:\Users\M323742\Anaconda3\envs\gym\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))
# True

# %%
env.close()
